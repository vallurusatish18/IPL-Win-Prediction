# %% [markdown]
# Github link: [Click here](https://github.com/vallurusatish18/IPL-Win-Prediction)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("matches.csv")

# %% [raw]
# df

# %%
new_df = df[["venue","team1","team2","toss_winner","winner"]]

# %%
new_df
# Out:
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# ...

# %%
new_df.isna().sum()
# Out:
# venue          0
# team1          0
# team2          0
# toss_winner    0
# winner         5
# dtype: int64

# %%
new_df = new_df.dropna()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
X = new_df.drop("winner",axis=1)
y = new_df["winner"]

# %%
y = le.fit_transform(y)

# %%
X = pd.get_dummies(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    max_depth=32,
    max_features=None,
    min_samples_leaf=7,
    min_samples_split=13,
    n_estimators=363,
    random_state=42
)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=32, max_features=None, min_samples_leaf=7,
#                        min_samples_split=13, n_estimators=363, random_state=42)

# %%
model.score(X_test,y_test)*100
# Out:
# 54.58715596330275

# %%
import joblib

# %%
joblib.dump(model,"model.joblib")
joblib.dump(le,"le.joblib")
# Out:
# ['le.joblib']

# %%
joblib.dump(X.columns.tolist(), "train_columns.pkl")
# Out:
# ['train_columns.pkl']
